# %%
import random

# %%
class Player():
    def __init__(self, wrong_letters=0, correct_letters=0):
        self.wrong_letters = wrong_letters
        self.correct_letters = correct_letters

# %%
class Game():
    def __init__(self, attempts = 6):
        self.attempts = attempts
        self.player = Player()
        self.wrong_letters_chosen = []
        self.words = ["house","bee", "elephant", "tree", "menu", "children", "story", "tennis", "kettle"]
        self.word_to_guess = random.choice(self.words)
        self.hangman = self.get_handman()

    def play(self):
        
        #Showing "empty" word that has to be guessed
        blank = [" __ " for w in range(len(self.word_to_guess))]
        print("\n" + (" ").join(blank))
        #Converting the word to be guessed into a list
        lst_to_guess = [w for w in self.word_to_guess]
        #Printing the first image of the hangman (when there are no wrong letters)
        print(self.hangman[0])
        

        while True:
            
            #Asking the player for input
            player_guess = (input("\nTry to guess a letter!: ").lower())
            
            #Error message if the input is not a letter
            if not player_guess.isalpha():
                print("Only letters allowed!")
                player_guess = (input("\nTry to guess a letter!: ").lower())
                
            #If the letter the player inputs is not in the secret word
            if player_guess not in lst_to_guess:

                self.player.wrong_letters = +1
                #If player already chose wrong letter
                if player_guess in self.wrong_letters_chosen:
                    print("You have already mentioned that letter, please try another one")
                    player_guess = (input("\nTry to guess a letter!: ").lower())
                
                #Add wrong letter to list so the player knows which letter she already chose
                self.wrong_letters_chosen.append(player_guess)
                self.attempts -= 1
                
                #When the player uses the 6 attempts, the game is finished
                if self.attempts == 0:
                
                    print(self.hangman[len(self.wrong_letters_chosen)])

                    print("\nSorry, you ran out of attempts!")

                    break
                    
                #If player still has attempts   
                else:
                    print(
                        f" Sorry! The letter '{player_guess}' is not in the secret word! You have {self.attempts} more attempts, try again!")
                    #Printing next image in hangman list, depending on failed inputs
                    print(self.hangman[len(self.wrong_letters_chosen)])
              
                #Show list with wrong letter chosen
                print(f" These are you wrong chosen letters until now: {self.wrong_letters_chosen}")

            #If the letter the player inputs is in the secret word 
            else:
                for i in range(len(lst_to_guess)):
                    if (lst_to_guess[i]) == player_guess:
                        blank[i] = lst_to_guess[i]
                        self.player.correct_letters += 1
                        
                        #If player guesses the word
                        if self.player.correct_letters == len(lst_to_guess):
                            print("Congratulations!! You guessed the secret word!")

            print((" ").join(blank))



    def get_handman(self):

        return ['''


   +---+

   |   |

       |

       |

       |

       |
 =========''', '''


   +---+
   |   |

   O   |

       |   

       |

       |
 =========''', '''


   +---+
   |   |

   O   |

   |   |

       |

       |

 =========''', '''



   +---+

   |   |

   O   |

  /|   |

       |

       |
 =========''', '''

   +---+
   |   |
   O   |
  /|\  |
       |
       |
 =========''', '''

  +---+
   |   |

   O   |
  /|\  |
  /    |

       |
 =========''', '''


   +---+

   |   |

   O   |

  /|\  |

  / \  |

       |

  =========''']

# %%
if __name__ == '__main__':
    print("Welcome to the Hangman! Here's the secret word:")
    game = Game()
    game.play()
# Out:
# Welcome to the Hangman! Here's the secret word:
#
#  __   __   __   __   __   __   __   __
#
#
#
#    +---+
#
#    |   |
#
#        |
#
#        |
#
#        |
#
#        |
#  =========
#
# Try to guess a letter!: a
#  Sorry! The letter 'a' is not in the secret word! You have 5 more attempts, try again!
#
#
#
#    +---+
#    |   |
#
#    O   |
#
#        |
#
#        |
#
#        |
#  =========
#  These are you wrong chosen letters until now: ['a']
#  __   __   __   __   __   __   __   __
#
# Try to guess a letter!: l
#  __   __   __  l  __   __   __   __
#
# Try to guess a letter!: c
# c  __   __  l  __   __   __   __
#
# Try to guess a letter!: o
#  Sorry! The letter 'o' is not in the secret word! You have 4 more attempts, try again!
#
#
#
#    +---+
#    |   |
#
#    O   |
#
#    |   |
#
#        |
#
#        |
#
#  =========
#  These are you wrong chosen letters until now: ['a', 'o']
# c  __   __  l  __   __   __   __
#
# Try to guess a letter!: m
#  Sorry! The letter 'm' is not in the secret word! You have 3 more attempts, try again!
#
#
#
#
#    +---+
#
#    |   |
#
#    O   |
#
#   /|   |
#
#        |
#
#        |
#  =========
#  These are you wrong chosen letters until now: ['a', 'o', 'm']
# c  __   __  l  __   __   __   __
#
# Try to guess a letter!: i
# c  __  i l  __   __   __   __
#
# Try to guess a letter!: u
#  Sorry! The letter 'u' is not in the secret word! You have 2 more attempts, try again!
#
#
#    +---+
#    |   |
#    O   |
#   /|\  |
#        |
#        |
#  =========
#  These are you wrong chosen letters until now: ['a', 'o', 'm', 'u']
# c  __  i l  __   __   __   __
#
# Try to guess a letter!: e
# c  __  i l  __   __  e  __
#
# Try to guess a letter!: r
# c  __  i l  __  r e  __
#
# Try to guess a letter!: h
# c h i l  __  r e  __
#
# Try to guess a letter!: p
#  Sorry! The letter 'p' is not in the secret word! You have 1 more attempts, try again!
#
#
#   +---+
#    |   |
#
#    O   |
#   /|\  |
#   /    |
#
#        |
#  =========
#  These are you wrong chosen letters until now: ['a', 'o', 'm', 'u', 'p']
# c h i l  __  r e  __
#
# Try to guess a letter!: d
# c h i l d r e  __
#
# Try to guess a letter!: n
# Congratulations!! You guessed the secret word!
# c h i l d r e n
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-1c9b2e705a50> in <module>
#       2     print("Welcome to the Hangman! Here's the secret word:")
#       3     game = Game()
# ----> 4     game.play()
#
# <ipython-input-3-a9a2bcd7b819> in play(self)
#      22
#      23             #Asking the player for input
# ---> 24             player_guess = (input("\nTry to guess a letter!: ").lower())
#      25
#      26             #Error message if the input is not a letter
#
# /usr/local/Cellar/jupyterlab/2.1.3/libexec/lib/python3.8/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# /usr/local/Cellar/jupyterlab/2.1.3/libexec/lib/python3.8/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
